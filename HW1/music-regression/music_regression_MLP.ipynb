# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import numpy as np
# Preprocessing

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder, StandardScaler
from torch.utils.data import Dataset, TensorDataset

# %%
class CustomTensorDataset(Dataset):
    """TensorDataset with support of transforms.
    """
    def __init__(self, tensors, transform=None):
        #assert all(tensors[0].size(0) == tensor.size(0) for tensor in tensors)
        self.tensors = tensors
        self.transform = transform

    def __getitem__(self, index):
        x = self.tensors[0][index]

        if self.transform:
            x = self.transform(x)

        y = self.tensors[1][index]

        return x, y

    def __len__(self):
        return self.tensors[0].size(0)

# %%
data = pd.read_csv('data_train.csv')
data = data.drop(['filename'],axis=1)
y = data.loc[:, 'label']
scaler = StandardScaler()

X = scaler.fit_transform(np.array(data.iloc[:, :-1], dtype = float))

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1)
X_train, y_train = X, y
print(len(y_train))
print(len(y_val))
X_train.shape
X_train = torch.from_numpy(np.array(X_train)).float()
y_train = torch.from_numpy(np.array(y_train)).float()
X_val = torch.from_numpy(np.array(X_val)).float()
y_val = torch.from_numpy(np.array(y_val)).float()
X = CustomTensorDataset(tensors=(X_train, y_train))
Valid = CustomTensorDataset(tensors=(X_val, y_val))
# Out:
# 220
# 22

# %%
data_test = pd.read_csv('data_test.csv')
data_test = data_test.drop(['filename'],axis=1)
scaler = StandardScaler()

X_test = scaler.fit_transform(np.array(data_test.iloc[:, :], dtype = float))
X_test.shape
X_test = torch.from_numpy(np.array(X_test)).float()
y_test = torch.FloatTensor(X_test.shape[0])
Test = CustomTensorDataset(tensors=(X_test, y_test))

# %%
# LENet
# Model structure
class LENet(nn.Module):
    def __init__(self):
        super(LENet, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(16*5*5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 1)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16*5*5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
class mlpNet(torch.nn.Module):
    def __init__(self, D_in) :
        super(mlpNet, self).__init__()
        self.linear1 = nn.Linear(D_in, 256)
        self.bn1 = nn.BatchNorm1d(256)
        self.relu = nn.ReLU()
        self.linear2 = nn.Linear(256, 128)
        self.bn2 = nn.BatchNorm1d(128)
        self.linear3 = nn.Linear(128, 64)
        self.bn3 = nn.BatchNorm1d(64)
        self.linear4 = nn.Linear(64, 1)
    
    def forward(self, x):
        x = self.relu(self.bn1(self.linear1(x)))
        x = self.relu(self.bn2(self.linear2(x)))
        x = self.relu(self.bn3(self.linear3(x)))
        x = self.linear4(x)
        return x

# %%
trainLoader = torch.utils.data.DataLoader(X, batch_size=4, shuffle=True, num_workers=2)
valLoader = torch.utils.data.DataLoader(Valid, batch_size=1, shuffle=False, num_workers=2)
testLoader = torch.utils.data.DataLoader(Test, batch_size=1, shuffle=False, num_workers=2)

# %%
MLP_model = mlpNet(25)
MLP_model = MLP_model.cuda()
# loss
criterion = nn.MSELoss(reduction='sum')
# optimizer
learning_rate = 1e-3
optimizer = torch.optim.Adam(MLP_model.parameters(), lr = learning_rate)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

# %%
# GPU
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print('GPU state:', device)
# Out:
# GPU state: cuda:0

# %%
def val(valLoader, model):
    with torch.no_grad():
        model.eval()
        total_loss = 0
        for data in valLoader:
            inputs, label = data
            inputs, label = inputs.to(device), label.to(device)
            MLP_model = model.cuda()
            outputs = model(inputs)
            outputs = outputs[0][0]
            #print('label:', label)
            total_loss += np.abs(np.sum((label - outputs).cpu().numpy()))
        return total_loss

# %%
def train(model):
    validation_error = []
    patience = 10
    last_loss = 1e9
    trigger_times = 0
    total_epoch = 200
    for epoch in range(total_epoch):
        running_loss = 0.0
        for times, data in enumerate(trainLoader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            #print(inputs.shape)
            # Zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = model(inputs)
            outputs = outputs.reshape(-1)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            if times+1 == len(trainLoader):
                print('[%d/%d, %d/%d] loss: %.3f' % (epoch+1, total_epoch, times+1, len(trainLoader), running_loss))
        validation_error.append(val(valLoader, model))
        print('validation_error:', validation_error[-1])
        if validation_error[-1] > last_loss:
            trigger_times += 1
            print('trigger times:', trigger_times)
        else:
            trigger_times = 0
            print('trigger times: 0')
        if trigger_times >= patience:
            print('Early stopping!\nStart to test process.')
            break
        last_loss = validation_error[-1]
    print('Finished Training')

# %%
train(MLP_model)
# Out:
# [1/200, 55/55] loss: 41.302
# validation_error: 4.738628715276718
# trigger times: 0
# [2/200, 55/55] loss: 19.299
# validation_error: 2.2750363945961
# trigger times: 0
# [3/200, 55/55] loss: 11.456
# validation_error: 2.075043797492981
# trigger times: 0
# [4/200, 55/55] loss: 6.289
# validation_error: 2.5136982798576355
# trigger times: 1
# [5/200, 55/55] loss: 2.959
# validation_error: 1.459737628698349
# trigger times: 0
# [6/200, 55/55] loss: 2.138
# validation_error: 1.4134275913238525
# trigger times: 0
# [7/200, 55/55] loss: 1.373
# validation_error: 0.9549066424369812
# trigger times: 0
# [8/200, 55/55] loss: 0.924
# validation_error: 0.9613268375396729
# trigger times: 1
# [9/200, 55/55] loss: 1.385
# validation_error: 0.9294813871383667
# trigger times: 0
# [10/200, 55/55] loss: 2.627
# validation_error: 1.3834345638751984
# trigger times: 1
# [11/200, 55/55] loss: 3.017
# validation_error: 1.2279190719127655
# trigger times: 0
# [12/200, 55/55] loss: 1.570
# validation_error: 0.609367847442627
# trigger times: 0
# [13/200, 55/55] loss: 1.155
# validation_error: 0.902969479560852
# trigger times: 1
# [14/200, 55/55] loss: 0.866
# validation_error: 0.805552214384079
# trigger times: 0
# [15/200, 55/55] loss: 0.913
# validation_error: 0.7933783233165741
# trigger times: 0
# [16/200, 55/55] loss: 0.618
# validation_error: 0.7230817973613739
# trigger times: 0
# [17/200, 55/55] loss: 0.707
# validation_error: 0.9308426678180695
# trigger times: 1
# [18/200, 55/55] loss: 0.845
# validation_error: 0.5972944498062134
# trigger times: 0
# [19/200, 55/55] loss: 0.931
# validation_error: 0.7705918550491333
# trigger times: 1
# [20/200, 55/55] loss: 0.794
# validation_error: 0.62481489777565
# trigger times: 0
# [21/200, 55/55] loss: 0.554
# validation_error: 0.7685045599937439
# trigger times: 1
# [22/200, 55/55] loss: 0.429
# validation_error: 0.5347296595573425
# trigger times: 0
# [23/200, 55/55] loss: 0.333
# validation_error: 0.7154547274112701
# trigger times: 1
# [24/200, 55/55] loss: 0.274
# validation_error: 0.5726324021816254
# trigger times: 0
# [25/200, 55/55] loss: 0.195
# validation_error: 0.42698031663894653
# trigger times: 0
# [26/200, 55/55] loss: 0.205
# validation_error: 0.6470178067684174
# trigger times: 1
# [27/200, 55/55] loss: 0.248
# validation_error: 0.5140627324581146
# trigger times: 0
# [28/200, 55/55] loss: 0.267
# validation_error: 0.867342084646225
# trigger times: 1
# [29/200, 55/55] loss: 0.366
# validation_error: 0.49875882267951965
# trigger times: 0
# [30/200, 55/55] loss: 0.423
# validation_error: 0.9393903017044067
# trigger times: 1
# [31/200, 55/55] loss: 0.435
# validation_error: 0.7686631381511688
# trigger times: 0
# [32/200, 55/55] loss: 0.564
# validation_error: 0.7188120484352112
# trigger times: 0
# [33/200, 55/55] loss: 0.611
# validation_error: 1.0755128860473633
# trigger times: 1
# [34/200, 55/55] loss: 0.566
# validation_error: 0.9651042222976685
# trigger times: 0
# [35/200, 55/55] loss: 0.460
# validation_error: 0.8028495013713837
# trigger times: 0
# [36/200, 55/55] loss: 0.584
# validation_error: 1.0016517639160156
# trigger times: 1
# [37/200, 55/55] loss: 0.750
# validation_error: 0.9043410122394562
# trigger times: 0
# [38/200, 55/55] loss: 0.780
# validation_error: 0.8743464350700378
# trigger times: 0
# [39/200, 55/55] loss: 1.084
# validation_error: 1.3969478607177734
# trigger times: 1
# [40/200, 55/55] loss: 0.993
# validation_error: 1.1041920483112335
# trigger times: 0
# [41/200, 55/55] loss: 0.662
# validation_error: 0.9922526180744171
# trigger times: 0
# [42/200, 55/55] loss: 0.590
# validation_error: 0.9022234976291656
# trigger times: 0
# [43/200, 55/55] loss: 0.605
# validation_error: 1.1578039228916168
# trigger times: 1
# [44/200, 55/55] loss: 0.556
# validation_error: 0.8676674365997314
# trigger times: 0
# [45/200, 55/55] loss: 0.515
# validation_error: 0.4899214804172516
# trigger times: 0
# [46/200, 55/55] loss: 0.549
# validation_error: 0.8883332312107086
# trigger times: 1
# [47/200, 55/55] loss: 0.475
# validation_error: 0.5872148871421814
# trigger times: 0
# [48/200, 55/55] loss: 0.456
# validation_error: 0.47324806451797485
# trigger times: 0
# [49/200, 55/55] loss: 0.350
# validation_error: 0.4428655803203583
# trigger times: 0
# [50/200, 55/55] loss: 0.318
# validation_error: 0.5581014454364777
# trigger times: 1
# [51/200, 55/55] loss: 0.269
# validation_error: 0.7355383634567261
# trigger times: 2
# [52/200, 55/55] loss: 0.348
# validation_error: 0.6649779677391052
# trigger times: 0
# [53/200, 55/55] loss: 0.336
# validation_error: 0.3468742072582245
# trigger times: 0
# [54/200, 55/55] loss: 0.311
# validation_error: 0.5428736805915833
# trigger times: 1
# [55/200, 55/55] loss: 0.288
# validation_error: 0.5512459576129913
# trigger times: 2
# [56/200, 55/55] loss: 0.308
# validation_error: 0.593284547328949
# trigger times: 3
# [57/200, 55/55] loss: 0.293
# validation_error: 0.6233043670654297
# trigger times: 4
# [58/200, 55/55] loss: 0.268
# validation_error: 0.8250785171985626
# trigger times: 5
# [59/200, 55/55] loss: 0.259
# validation_error: 0.6169973015785217
# trigger times: 0
# [60/200, 55/55] loss: 0.223
# validation_error: 0.46781057119369507
# trigger times: 0
# [61/200, 55/55] loss: 0.190
# validation_error: 0.5873476266860962
# trigger times: 1
# [62/200, 55/55] loss: 0.209
# validation_error: 0.6485472023487091
# trigger times: 2
# [63/200, 55/55] loss: 0.241
# validation_error: 0.6795454621315002
# trigger times: 3
# [64/200, 55/55] loss: 0.311
# validation_error: 0.5518555045127869
# trigger times: 0
# [65/200, 55/55] loss: 0.357
# validation_error: 0.8513527810573578
# trigger times: 1
# [66/200, 55/55] loss: 0.412
# validation_error: 0.737480640411377
# trigger times: 0
# [67/200, 55/55] loss: 0.364
# validation_error: 0.8418864011764526
# trigger times: 1
# [68/200, 55/55] loss: 0.482
# validation_error: 0.6773739159107208
# trigger times: 0
# [69/200, 55/55] loss: 0.507
# validation_error: 0.9145259261131287
# trigger times: 1
# [70/200, 55/55] loss: 0.503
# validation_error: 0.8326299488544464
# trigger times: 0
# [71/200, 55/55] loss: 0.970
# validation_error: 0.9528752267360687
# trigger times: 1
# [72/200, 55/55] loss: 1.115
# validation_error: 1.131685197353363
# trigger times: 2
# [73/200, 55/55] loss: 1.020
# validation_error: 1.6958452463150024
# trigger times: 3
# [74/200, 55/55] loss: 1.141
# validation_error: 1.0601734220981598
# trigger times: 0
# [75/200, 55/55] loss: 1.059
# validation_error: 0.9047532677650452
# trigger times: 0
# [76/200, 55/55] loss: 0.825
# validation_error: 0.7361503839492798
# trigger times: 0
# [77/200, 55/55] loss: 0.924
# validation_error: 0.8612432181835175
# trigger times: 1
# [78/200, 55/55] loss: 0.746
# validation_error: 0.8206883370876312
# trigger times: 0
# [79/200, 55/55] loss: 0.700
# validation_error: 0.9503361284732819
# trigger times: 1
# [80/200, 55/55] loss: 0.725
# validation_error: 0.7618087530136108
# trigger times: 0
# [81/200, 55/55] loss: 0.627
# validation_error: 0.7336130142211914
# trigger times: 0
# [82/200, 55/55] loss: 0.415
# validation_error: 0.7635814249515533
# trigger times: 1
# [83/200, 55/55] loss: 0.611
# validation_error: 0.6222582161426544
# trigger times: 0
# [84/200, 55/55] loss: 0.371
# validation_error: 0.8940023183822632
# trigger times: 1
# [85/200, 55/55] loss: 0.356
# validation_error: 0.6948064863681793
# trigger times: 0
# [86/200, 55/55] loss: 0.422
# validation_error: 0.7614480257034302
# trigger times: 1
# [87/200, 55/55] loss: 0.368
# validation_error: 0.7814452052116394
# trigger times: 2
# [88/200, 55/55] loss: 0.398
# validation_error: 0.9110177159309387
# trigger times: 3
# [89/200, 55/55] loss: 0.339
# validation_error: 0.7976545989513397
# trigger times: 0
# [90/200, 55/55] loss: 0.227
# validation_error: 0.4611041843891144
# trigger times: 0
# [91/200, 55/55] loss: 0.123
# validation_error: 0.25752338767051697
# trigger times: 0
# [92/200, 55/55] loss: 0.102
# validation_error: 0.2898433804512024
# trigger times: 1
# [93/200, 55/55] loss: 0.145
# validation_error: 0.318339467048645
# trigger times: 2
# [94/200, 55/55] loss: 0.159
# validation_error: 0.44740763306617737
# trigger times: 3
# [95/200, 55/55] loss: 0.128
# validation_error: 0.452313095331192
# trigger times: 4
# [96/200, 55/55] loss: 0.116
# validation_error: 0.3824196457862854
# trigger times: 0
# [97/200, 55/55] loss: 0.126
# validation_error: 0.26383695006370544
# trigger times: 0
# [98/200, 55/55] loss: 0.138
# validation_error: 0.2925778329372406
# trigger times: 1
# [99/200, 55/55] loss: 0.207
# validation_error: 0.4326741397380829
# trigger times: 2
# [100/200, 55/55] loss: 0.188
# validation_error: 0.5596115291118622
# trigger times: 3
# [101/200, 55/55] loss: 0.222
# validation_error: 0.6042018234729767
# trigger times: 4
# [102/200, 55/55] loss: 0.316
# validation_error: 0.3803352117538452
# trigger times: 0
# [103/200, 55/55] loss: 0.265
# validation_error: 0.7777648270130157
# trigger times: 1
# [104/200, 55/55] loss: 0.292
# validation_error: 0.5467417538166046
# trigger times: 0
# [105/200, 55/55] loss: 0.283
# validation_error: 0.6429702341556549
# trigger times: 1
# [106/200, 55/55] loss: 0.347
# validation_error: 0.7843171060085297
# trigger times: 2
# [107/200, 55/55] loss: 0.433
# validation_error: 0.5895886719226837
# trigger times: 0
# [108/200, 55/55] loss: 0.470
# validation_error: 1.1973452270030975
# trigger times: 1
# [109/200, 55/55] loss: 0.682
# validation_error: 1.261234849691391
# trigger times: 2
# [110/200, 55/55] loss: 0.718
# validation_error: 0.7747908532619476
# trigger times: 0
# [111/200, 55/55] loss: 0.691
# validation_error: 0.9353571534156799
# trigger times: 1
# [112/200, 55/55] loss: 0.829
# validation_error: 1.1685756742954254
# trigger times: 2
# [113/200, 55/55] loss: 0.846
# validation_error: 1.3879025876522064
# trigger times: 3
# [114/200, 55/55] loss: 0.826
# validation_error: 1.2815847992897034
# trigger times: 0
# [115/200, 55/55] loss: 0.809
# validation_error: 0.670695960521698
# trigger times: 0
# [116/200, 55/55] loss: 0.590
# validation_error: 0.6189575791358948
# trigger times: 0
# [117/200, 55/55] loss: 0.432
# validation_error: 0.6541233658790588
# trigger times: 1
# [118/200, 55/55] loss: 0.602
# validation_error: 0.8249340951442719
# trigger times: 2
# [119/200, 55/55] loss: 0.409
# validation_error: 0.5715291798114777
# trigger times: 0
# [120/200, 55/55] loss: 0.264
# validation_error: 0.44931760430336
# trigger times: 0
# [121/200, 55/55] loss: 0.184
# validation_error: 0.362029105424881
# trigger times: 0
# [122/200, 55/55] loss: 0.157
# validation_error: 0.28147265315055847
# trigger times: 0
# [123/200, 55/55] loss: 0.119
# validation_error: 0.48179301619529724
# trigger times: 1
# [124/200, 55/55] loss: 0.096
# validation_error: 0.42107531428337097
# trigger times: 0
# [125/200, 55/55] loss: 0.075
# validation_error: 0.28883641958236694
# trigger times: 0
# [126/200, 55/55] loss: 0.083
# validation_error: 0.19384071230888367
# trigger times: 0
# [127/200, 55/55] loss: 0.072
# validation_error: 0.1692347228527069
# trigger times: 0
# [128/200, 55/55] loss: 0.076
# validation_error: 0.23887142539024353
# trigger times: 1
# [129/200, 55/55] loss: 0.056
# validation_error: 0.281272292137146
# trigger times: 2
# [130/200, 55/55] loss: 0.076
# validation_error: 0.2874733507633209
# trigger times: 3
# [131/200, 55/55] loss: 0.102
# validation_error: 0.38750579953193665
# trigger times: 4
# [132/200, 55/55] loss: 0.123
# validation_error: 0.3563925623893738
# trigger times: 0
# [133/200, 55/55] loss: 0.107
# validation_error: 0.2672339677810669
# trigger times: 0
# [134/200, 55/55] loss: 0.118
# validation_error: 0.3548891842365265
# trigger times: 1
# [135/200, 55/55] loss: 0.144
# validation_error: 0.4929324686527252
# trigger times: 2
# [136/200, 55/55] loss: 0.128
# validation_error: 0.4692412316799164
# trigger times: 0
# [137/200, 55/55] loss: 0.140
# validation_error: 0.5519123673439026
# trigger times: 1
# [138/200, 55/55] loss: 0.205
# validation_error: 0.5150465071201324
# trigger times: 0
# [139/200, 55/55] loss: 0.227
# validation_error: 0.6259618997573853
# trigger times: 1
# [140/200, 55/55] loss: 0.289
# validation_error: 0.7793424129486084
# trigger times: 2
# [141/200, 55/55] loss: 0.281
# validation_error: 0.5956336557865143
# trigger times: 0
# [142/200, 55/55] loss: 0.268
# validation_error: 0.552588164806366
# trigger times: 0
# [143/200, 55/55] loss: 0.247
# validation_error: 0.8780140578746796
# trigger times: 1
# [144/200, 55/55] loss: 0.340
# validation_error: 0.47879377007484436
# trigger times: 0
# [145/200, 55/55] loss: 0.306
# validation_error: 0.648321807384491
# trigger times: 1
# [146/200, 55/55] loss: 0.287
# validation_error: 0.5468184053897858
# trigger times: 0
# [147/200, 55/55] loss: 0.456
# validation_error: 0.5867694318294525
# trigger times: 1
# [148/200, 55/55] loss: 0.400
# validation_error: 0.8413226902484894
# trigger times: 2
# [149/200, 55/55] loss: 0.363
# validation_error: 0.7487667202949524
# trigger times: 0
# [150/200, 55/55] loss: 0.324
# validation_error: 0.5928997099399567
# trigger times: 0
# [151/200, 55/55] loss: 0.268
# validation_error: 0.3576621413230896
# trigger times: 0
# [152/200, 55/55] loss: 0.272
# validation_error: 0.38555803894996643
# trigger times: 1
# [153/200, 55/55] loss: 0.197
# validation_error: 0.431666761636734
# trigger times: 2
# [154/200, 55/55] loss: 0.174
# validation_error: 0.560754269361496
# trigger times: 3
# [155/200, 55/55] loss: 0.164
# validation_error: 0.3921184241771698
# trigger times: 0
# [156/200, 55/55] loss: 0.137
# validation_error: 0.3527621328830719
# trigger times: 0
# [157/200, 55/55] loss: 0.107
# validation_error: 0.2482239305973053
# trigger times: 0
# [158/200, 55/55] loss: 0.114
# validation_error: 0.33821341395378113
# trigger times: 1
# [159/200, 55/55] loss: 0.118
# validation_error: 0.36410993337631226
# trigger times: 2
# [160/200, 55/55] loss: 0.099
# validation_error: 0.4373109042644501
# trigger times: 3
# [161/200, 55/55] loss: 0.083
# validation_error: 0.32035285234451294
# trigger times: 0
# [162/200, 55/55] loss: 0.074
# validation_error: 0.33984634280204773
# trigger times: 1
# [163/200, 55/55] loss: 0.062
# validation_error: 0.2389390468597412
# trigger times: 0
# [164/200, 55/55] loss: 0.069
# validation_error: 0.2837318181991577
# trigger times: 1
# [165/200, 55/55] loss: 0.094
# validation_error: 0.35850095748901367
# trigger times: 2
# [166/200, 55/55] loss: 0.116
# validation_error: 0.35353216528892517
# trigger times: 0
# [167/200, 55/55] loss: 0.139
# validation_error: 0.44012191891670227
# trigger times: 1
# [168/200, 55/55] loss: 0.124
# validation_error: 0.34696951508522034
# trigger times: 0
# [169/200, 55/55] loss: 0.147
# validation_error: 0.447666198015213
# trigger times: 1
# [170/200, 55/55] loss: 0.172
# validation_error: 0.5239305794239044
# trigger times: 2
# [171/200, 55/55] loss: 0.258
# validation_error: 0.6304998695850372
# trigger times: 3
# [172/200, 55/55] loss: 0.208
# validation_error: 0.5187731683254242
# trigger times: 0
# [173/200, 55/55] loss: 0.341
# validation_error: 0.7692749202251434
# trigger times: 1
# [174/200, 55/55] loss: 0.511
# validation_error: 0.4490080177783966
# trigger times: 0
# [175/200, 55/55] loss: 0.590
# validation_error: 0.6125141382217407
# trigger times: 1
# [176/200, 55/55] loss: 0.566
# validation_error: 0.7751307189464569
# trigger times: 2
# [177/200, 55/55] loss: 0.571
# validation_error: 1.0387137830257416
# trigger times: 3
# [178/200, 55/55] loss: 0.817
# validation_error: 1.3548618853092194
# trigger times: 4
# [179/200, 55/55] loss: 0.877
# validation_error: 0.908210813999176
# trigger times: 0
# [180/200, 55/55] loss: 0.842
# validation_error: 0.6162841618061066
# trigger times: 0
# [181/200, 55/55] loss: 0.571
# validation_error: 0.5741933882236481
# trigger times: 0
# [182/200, 55/55] loss: 0.418
# validation_error: 0.5575470626354218
# trigger times: 0
# [183/200, 55/55] loss: 0.402
# validation_error: 0.6725874245166779
# trigger times: 1
# [184/200, 55/55] loss: 0.208
# validation_error: 0.30017945170402527
# trigger times: 0
# [185/200, 55/55] loss: 0.102
# validation_error: 0.25992706418037415
# trigger times: 0
# [186/200, 55/55] loss: 0.062
# validation_error: 0.22302839159965515
# trigger times: 0
# [187/200, 55/55] loss: 0.038
# validation_error: 0.2592030465602875
# trigger times: 1
# [188/200, 55/55] loss: 0.024
# validation_error: 0.13236188888549805
# trigger times: 0
# [189/200, 55/55] loss: 0.017
# validation_error: 0.0976513922214508
# trigger times: 0
# [190/200, 55/55] loss: 0.010
# validation_error: 0.1026662290096283
# trigger times: 1
# [191/200, 55/55] loss: 0.012
# validation_error: 0.12567377090454102
# trigger times: 2
# [192/200, 55/55] loss: 0.017
# validation_error: 0.1583223044872284
# trigger times: 3
# [193/200, 55/55] loss: 0.027
# validation_error: 0.1732301414012909
# trigger times: 4
# [194/200, 55/55] loss: 0.021
# validation_error: 0.1263394057750702
# trigger times: 0
# [195/200, 55/55] loss: 0.022
# validation_error: 0.14697405695915222
# trigger times: 1
# [196/200, 55/55] loss: 0.019
# validation_error: 0.12025317549705505
# trigger times: 0
# [197/200, 55/55] loss: 0.021
# validation_error: 0.15296047925949097
# trigger times: 1
# [198/200, 55/55] loss: 0.024
# validation_error: 0.13815733790397644
# trigger times: 0
# [199/200, 55/55] loss: 0.030
# validation_error: 0.13170769810676575
# trigger times: 0
# [200/200, 55/55] loss: 0.036
# validation_error: 0.2023947536945343
# trigger times: 1
# Finished Training

# %%
PATH = './MLP_Net.pth'
torch.save(MLP_model.state_dict(), PATH)

# %%
PATH = './MLP_Net.pth'
net = mlpNet(25)
net.load_state_dict(torch.load(PATH))
net = net.cuda()

# %%
# inference
predicted_res = []
with torch.no_grad():
    net.eval()
    for data in testLoader:
        input, label = data
        input = input.to(device)
        output = net(input)
        output = output.cpu().numpy()
        predicted_res.append(output[0][0])
submission_df = pd.read_csv('sample_submission.csv')
submission_df['score'] = predicted_res

#submission_df = submission_df.drop(['score'], axis=1)
#submission_df = submission_df.insert(1, "score", predicted_res)
submission_df.to_csv('submission/MLP_submission.csv', index=False)
